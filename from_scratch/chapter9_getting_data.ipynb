# %%
# webscraping

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = ("http://raw.githubusercontent.com/joelgrus/data/master/getting-data.html")
html = requests.get(url).text
soup = BeautifulSoup(html, 'html5lib')

# %%
# find the first paragraphs <p> tag
first_paragraph = soup.find('p')
first_paragraph
# Out:
# <p id="p1">This is the first paragraph.</p>

# %%
# get tex contents of a Tag
first_paragraph_text = soup.p.text
print(first_paragraph_text)
first_paragraph_words = soup.p.text.split()
print(first_paragraph_words)
# Out:
# This is the first paragraph.
# ['This', 'is', 'the', 'first', 'paragraph.']

# %%
# extract a tag's attributes by treating it like a dict
first_paragraph_id = soup.p['id']
print(first_paragraph_id)
first_paragraph_id2 = soup.p.get('id')
first_paragraph_id2
# Out:
# p1
# 'p1'

# %%
# get multiple tags at once
all_paragraphs = soup.find_all('p')
print(all_paragraphs)
paragraphs_with_ids = [p for p in soup('p') if p.get('id')]
print(paragraphs_with_ids)
# Out:
# [<p id="p1">This is the first paragraph.</p>, <p class="important">This is the second paragraph.</p>]
# [<p id="p1">This is the first paragraph.</p>]

# %%
# find tag with specific classes
important_paragraphs = soup('p', {'class':'important'})
important_paragraphs2 = soup('p', 'important')
important_paragraphs3 = [p for p in soup('p') if 'important' in p.get('class', [])]

print(important_paragraphs)
print(important_paragraphs2)
print(important_paragraphs3)
# Out:
# [<p class="important">This is the second paragraph.</p>]
# [<p class="important">This is the second paragraph.</p>]
# [<p class="important">This is the second paragraph.</p>]

# %%
spans_inside_divs = [span for div in soup('div') for span in div('span')]
spans_inside_divs
# Out:
# [<span id="name">Joel</span>,
#  <span id="twitter">@joelgrus</span>,
#  <span id="email">joelgrus-at-gmail</span>]

# %%
url= 'https://www.house.gov/representatives'
text = requests.get(url).text
soup = BeautifulSoup(text, "html5lib")
all_urls = [a['href'] for a in soup('a') if a.has_attr('href')]
print(len(all_urls))
# Out:
# 967

# %%
import re
regex = r"^https?://.*\.house\.gov/?$"
good_urls = [url for url in all_urls if re.match(regex, url)]

# %%
good_urls.sort()
good_urls
# Out:
# ['https://adams.house.gov',
#  'https://adams.house.gov',
#  'https://adamsmith.house.gov/',
#  'https://adamsmith.house.gov/',
#  'https://aderholt.house.gov/',
#  'https://aderholt.house.gov/',
#  'https://adriansmith.house.gov/',
#  'https://adriansmith.house.gov/',
#  'https://aguilar.house.gov/',
#  'https://aguilar.house.gov/',
#  'https://alceehastings.house.gov/',
#  'https://alceehastings.house.gov/',
#  'https://algreen.house.gov',
#  'https://algreen.house.gov',
#  'https://allen.house.gov',
#  'https://allen.house.gov',
#  'https://allred.house.gov/',
#  'https://allred.house.gov/',
#  'https://amodei.house.gov',
#  'https://amodei.house.gov',
#  'https://andylevin.house.gov/',
#  'https://andylevin.house.gov/',
#  'https://anthonybrown.house.gov',
#  'https://anthonybrown.house.gov',
#  'https://anthonygonzalez.house.gov',
#  'https://anthonygonzalez.house.gov',
#  'https://armstrong.house.gov',
#  'https://armstrong.house.gov',
#  'https://arrington.house.gov',
#  'https://arrington.house.gov',
#  'https://auchincloss.house.gov',
#  'https://auchincloss.house.gov',
#  'https://austinscott.house.gov/',
#  'https://austinscott.house.gov/',
#  'https://axne.house.gov/',
#  'https://axne.house.gov/',
#  'https://babin.house.gov',
#  'https://babin.house.gov',
#  'https://bacon.house.gov',
#  'https://bacon.house.gov',
#  'https://baird.house.gov/',
#  'https://baird.house.gov/',
#  'https://balderson.house.gov',
#  'https://balderson.house.gov',
#  'https://banks.house.gov',
#  'https://banks.house.gov',
#  'https://barr.house.gov/',
#  'https://barr.house.gov/',
#  'https://barragan.house.gov',
#  'https://barragan.house.gov',
#  'https://barrymoore.house.gov',
#  'https://barrymoore.house.gov',
#  'https://bass.house.gov/',
#  'https://bass.house.gov/',
#  'https://beatty.house.gov',
#  'https://beatty.house.gov',
#  'https://benniethompson.house.gov/',
#  'https://benniethompson.house.gov/',
#  'https://bentz.house.gov',
#  'https://bentz.house.gov',
#  'https://bera.house.gov',
#  'https://bera.house.gov',
#  'https://bergman.house.gov',
#  'https://bergman.house.gov',
#  'https://beyer.house.gov',
#  'https://beyer.house.gov',
#  'https://bice.house.gov',
#  'https://bice.house.gov',
#  'https://biggs.house.gov',
#  'https://biggs.house.gov',
#  'https://bilirakis.house.gov/',
#  'https://bilirakis.house.gov/',
#  'https://billjohnson.house.gov/',
#  'https://billjohnson.house.gov/',
#  'https://bishop.house.gov/',
#  'https://bishop.house.gov/',
#  'https://blakemoore.house.gov',
#  'https://blakemoore.house.gov',
#  'https://blumenauer.house.gov/',
#  'https://blumenauer.house.gov/',
#  'https://bluntrochester.house.gov',
#  'https://bluntrochester.house.gov',
#  'https://bobbyscott.house.gov',
#  'https://bobbyscott.house.gov',
#  'https://boebert.house.gov',
#  'https://boebert.house.gov',
#  'https://bonamici.house.gov',
#  'https://bonamici.house.gov',
#  'https://bost.house.gov/',
#  'https://bost.house.gov/',
#  'https://bourdeaux.house.gov',
#  'https://bourdeaux.house.gov',
#  'https://bowman.house.gov',
#  'https://bowman.house.gov',
#  'https://boyle.house.gov/',
#  'https://boyle.house.gov/',
#  'https://brooks.house.gov/',
#  'https://brooks.house.gov/',
#  'https://buchanan.house.gov/',
#  'https://buchanan.house.gov/',
#  'https://buck.house.gov/',
#  'https://buck.house.gov/',
#  'https://bucshon.house.gov/',
#  'https://bucshon.house.gov/',
#  'https://budd.house.gov',
#  'https://budd.house.gov',
#  'https://buddycarter.house.gov/',
#  'https://buddycarter.house.gov/',
#  'https://burchett.house.gov',
#  'https://burchett.house.gov',
#  'https://burgess.house.gov/',
#  'https://burgess.house.gov/',
#  'https://bush.house.gov',
#  'https://bush.house.gov',
#  'https://bustos.house.gov',
#  'https://bustos.house.gov',
#  'https://butterfield.house.gov',
#  'https://butterfield.house.gov',
#  'https://calvert.house.gov/',
#  'https://calvert.house.gov/',
#  'https://cammack.house.gov',
#  'https://cammack.house.gov',
#  'https://carbajal.house.gov',
#  'https://carbajal.house.gov',
#  'https://cardenas.house.gov',
#  'https://cardenas.house.gov',
#  'https://carl.house.gov',
#  'https://carl.house.gov',
#  'https://carson.house.gov/',
#  'https://carson.house.gov/',
#  'https://carter.house.gov/',
#  'https://carter.house.gov/',
#  'https://cartwright.house.gov',
#  'https://cartwright.house.gov',
#  'https://case.house.gov/',
#  'https://case.house.gov/',
#  'https://casten.house.gov',
#  'https://casten.house.gov',
#  'https://castor.house.gov/',
#  'https://castor.house.gov/',
#  'https://castro.house.gov',
#  'https://castro.house.gov',
#  'https://cawthorn.house.gov',
#  'https://cawthorn.house.gov',
#  'https://chabot.house.gov/',
#  'https://chabot.house.gov/',
#  'https://cheney.house.gov',
#  'https://cheney.house.gov',
#  'https://chrissmith.house.gov/',
#  'https://chrissmith.house.gov/',
#  'https://chu.house.gov/',
#  'https://chu.house.gov/',
#  'https://chuygarcia.house.gov/',
#  'https://chuygarcia.house.gov/',
#  'https://cicilline.house.gov/',
#  'https://cicilline.house.gov/',
#  'https://clarke.house.gov/',
#  'https://clarke.house.gov/',
#  'https://clayhiggins.house.gov',
#  'https://clayhiggins.house.gov',
#  'https://cleaver.house.gov',
#  'https://cleaver.house.gov',
#  'https://cline.house.gov',
#  'https://cline.house.gov',
#  'https://cloud.house.gov',
#  'https://cloud.house.gov',
#  'https://clyburn.house.gov/',
#  'https://clyburn.house.gov/',
#  'https://clyde.house.gov',
#  'https://clyde.house.gov',
#  'https://cohen.house.gov/',
#  'https://cohen.house.gov/',
#  'https://cole.house.gov',
#  'https://cole.house.gov',
#  'https://comer.house.gov/',
#  'https://comer.house.gov/',
#  'https://connolly.house.gov/',
#  'https://connolly.house.gov/',
#  'https://cooper.house.gov/',
#  'https://cooper.house.gov/',
#  'https://correa.house.gov',
#  'https://correa.house.gov',
#  'https://costa.house.gov/',
#  'https://costa.house.gov/',
#  'https://courtney.house.gov/',
#  'https://courtney.house.gov/',
#  'https://craig.house.gov',
#  'https://craig.house.gov',
#  'https://crawford.house.gov/',
#  'https://crawford.house.gov/',
#  'https://crenshaw.house.gov/',
#  'https://crenshaw.house.gov/',
#  'https://crist.house.gov',
#  'https://crist.house.gov',
#  'https://crow.house.gov/',
#  'https://crow.house.gov/',
#  'https://cuellar.house.gov/',
#  'https://cuellar.house.gov/',
#  'https://curtis.house.gov/',
#  'https://curtis.house.gov/',
#  'https://danbishop.house.gov',
#  'https://danbishop.house.gov',
#  'https://dankildee.house.gov',
#  'https://dankildee.house.gov',
#  'https://davids.house.gov/',
#  'https://davids.house.gov/',
#  'https://davidscott.house.gov/',
#  'https://davidscott.house.gov/',
#  'https://davidson.house.gov/',
#  'https://davidson.house.gov/',
#  'https://davis.house.gov',
#  'https://davis.house.gov',
#  'https://dean.house.gov',
#  'https://dean.house.gov',
#  'https://debbiedingell.house.gov/',
#  'https://debbiedingell.house.gov/',
#  'https://defazio.house.gov/',
#  'https://defazio.house.gov/',
#  'https://degette.house.gov',
#  'https://degette.house.gov',
#  'https://delauro.house.gov/',
#  'https://delauro.house.gov/',
#  'https://delbene.house.gov',
#  'https://delbene.house.gov',
#  'https://delgado.house.gov',
#  'https://delgado.house.gov',
#  'https://demings.house.gov',
#  'https://demings.house.gov',
#  'https://desaulnier.house.gov/',
#  'https://desaulnier.house.gov/',
#  'https://desjarlais.house.gov/',
#  'https://desjarlais.house.gov/',
#  'https://doggett.house.gov',
#  'https://doggett.house.gov',
#  'https://donalds.house.gov',
#  'https://donalds.house.gov',
#  'https://donyoung.house.gov/',
#  'https://donyoung.house.gov/',
#  'https://doyle.house.gov',
#  'https://doyle.house.gov',
#  'https://dunn.house.gov',
#  'https://dunn.house.gov',
#  'https://dustyjohnson.house.gov/',
#  'https://dustyjohnson.house.gov/',
#  'https://ebjohnson.house.gov',
#  'https://ebjohnson.house.gov',
#  'https://emmer.house.gov/',
#  'https://emmer.house.gov/',
#  'https://escobar.house.gov',
#  'https://escobar.house.gov',
#  'https://eshoo.house.gov/',
#  'https://eshoo.house.gov/',
#  'https://espaillat.house.gov',
#  'https://espaillat.house.gov',
#  'https://estes.house.gov/',
#  'https://estes.house.gov/',
#  'https://evans.house.gov/',
#  'https://evans.house.gov/',
#  'https://fallon.house.gov',
#  'https://fallon.house.gov',
#  'https://feenstra.house.gov',
#  'https://feenstra.house.gov',
#  'https://ferguson.house.gov',
#  'https://ferguson.house.gov',
#  'https://fernandez.house.gov',
#  'https://fernandez.house.gov',
#  'https://fischbach.house.gov',
#  'https://fischbach.house.gov',
#  'https://fitzgerald.house.gov',
#  'https://fitzgerald.house.gov',
#  'https://fitzpatrick.house.gov/',
#  'https://fitzpatrick.house.gov/',
#  'https://fleischmann.house.gov/',
#  'https://fleischmann.house.gov/',
#  'https://fletcher.house.gov',
#  'https://fletcher.house.gov',
#  'https://fortenberry.house.gov/',
#  'https://fortenberry.house.gov/',
#  'https://foster.house.gov',
#  'https://foster.house.gov',
#  'https://foxx.house.gov/',
#  'https://foxx.house.gov/',
#  'https://frankel.house.gov',
#  'https://frankel.house.gov',
#  'https://franklin.house.gov',
#  'https://franklin.house.gov',
#  'https://fudge.house.gov/',
#  'https://fudge.house.gov/',
#  'https://fulcher.house.gov/',
#  'https://fulcher.house.gov/',
#  'https://gaetz.house.gov',
#  'https://gaetz.house.gov',
#  'https://gallagher.house.gov',
#  'https://gallagher.house.gov',
#  'https://garamendi.house.gov/',
#  'https://garamendi.house.gov/',
#  'https://garbarino.house.gov',
#  'https://garbarino.house.gov',
#  'https://garretgraves.house.gov/',
#  'https://garretgraves.house.gov/',
#  'https://gibbs.house.gov/',
#  'https://gibbs.house.gov/',
#  'https://gimenez.house.gov',
#  'https://gimenez.house.gov',
#  'https://gohmert.house.gov/',
#  'https://gohmert.house.gov/',
#  'https://golden.house.gov',
#  'https://golden.house.gov',
#  'https://gomez.house.gov/',
#  'https://gomez.house.gov/',
#  'https://gonzales.house.gov',
#  'https://gonzales.house.gov',
#  'https://gonzalez-colon.house.gov',
#  'https://gonzalez-colon.house.gov',
#  'https://gonzalez.house.gov',
#  'https://gonzalez.house.gov',
#  'https://good.house.gov',
#  'https://good.house.gov',
#  'https://gooden.house.gov',
#  'https://gooden.house.gov',
#  'https://gosar.house.gov/',
#  'https://gosar.house.gov/',
#  'https://gottheimer.house.gov',
#  'https://gottheimer.house.gov',
#  'https://graves.house.gov/',
#  'https://graves.house.gov/',
#  'https://greene.house.gov',
#  'https://greene.house.gov',
#  'https://gregmurphy.house.gov',
#  'https://gregmurphy.house.gov',
#  'https://grijalva.house.gov/',
#  'https://grijalva.house.gov/',
#  'https://grothman.house.gov',
#  'https://grothman.house.gov',
#  'https://guest.house.gov',
#  'https://guest.house.gov',
#  'https://guthrie.house.gov/',
#  'https://guthrie.house.gov/',
#  'https://gwenmoore.house.gov',
#  'https://gwenmoore.house.gov',
#  'https://haaland.house.gov/',
#  'https://haaland.house.gov/',
#  'https://hagedorn.house.gov/',
#  'https://hagedorn.house.gov/',
#  'https://halrogers.house.gov/',
#  'https://halrogers.house.gov/',
#  'https://hankjohnson.house.gov/',
#  'https://hankjohnson.house.gov/',
#  'https://harder.house.gov/',
#  'https://harder.house.gov/',
#  'https://harris.house.gov/',
#  'https://harris.house.gov/',
#  'https://harshbarger.house.gov',
#  'https://harshbarger.house.gov',
#  'https://hartzler.house.gov/',
#  'https://hartzler.house.gov/',
#  'https://hayes.house.gov',
#  'https://hayes.house.gov',
#  'https://hern.house.gov',
#  'https://hern.house.gov',
#  'https://herrell.house.gov',
#  'https://herrell.house.gov',
#  'https://hice.house.gov/',
#  'https://hice.house.gov/',
#  'https://higgins.house.gov',
#  'https://higgins.house.gov',
#  'https://hill.house.gov/',
#  'https://hill.house.gov/',
#  'https://himes.house.gov/',
#  'https://himes.house.gov/',
#  'https://hinson.house.gov',
#  'https://hinson.house.gov',
#  'https://hollingsworth.house.gov',
#  'https://hollingsworth.house.gov',
#  'https://horsford.house.gov',
#  'https://horsford.house.gov',
#  'https://houlahan.house.gov/',
#  'https://houlahan.house.gov/',
#  'https://hoyer.house.gov/',
#  'https://hoyer.house.gov/',
#  'https://hudson.house.gov',
#  'https://hudson.house.gov',
#  'https://huffman.house.gov',
#  'https://huffman.house.gov',
#  'https://huizenga.house.gov/',
#  'https://huizenga.house.gov/',
#  'https://issa.house.gov',
#  'https://issa.house.gov',
#  'https://jackson.house.gov',
#  'https://jackson.house.gov',
#  'https://jacksonlee.house.gov/',
#  'https://jacksonlee.house.gov/',
#  'https://jacobs.house.gov',
#  'https://jacobs.house.gov',
#  'https://jasonsmith.house.gov',
#  'https://jasonsmith.house.gov',
#  'https://jayapal.house.gov',
#  'https://jayapal.house.gov',
#  'https://jeffduncan.house.gov/',
#  'https://jeffduncan.house.gov/',
#  'https://jeffries.house.gov',
#  'https://jeffries.house.gov',
#  'https://jhb.house.gov/',
#  'https://jhb.house.gov/',
#  'https://joewilson.house.gov/',
#  'https://joewilson.house.gov/',
#  'https://johnjoyce.house.gov/',
#  'https://johnjoyce.house.gov/',
#  'https://johnrose.house.gov/',
#  'https://johnrose.house.gov/',
#  'https://jones.house.gov',
#  'https://jones.house.gov',
#  'https://jordan.house.gov/',
#  'https://jordan.house.gov/',
#  'https://joyce.house.gov',
#  'https://joyce.house.gov',
#  'https://juliabrownley.house.gov',
#  'https://juliabrownley.house.gov',
#  'https://kahele.house.gov',
#  'https://kahele.house.gov',
#  'https://kaptur.house.gov/',
#  'https://kaptur.house.gov/',
#  'https://kathleenrice.house.gov',
#  'https://kathleenrice.house.gov',
#  'https://katko.house.gov/',
#  'https://katko.house.gov/',
#  'https://kaygranger.house.gov',
#  'https://kaygranger.house.gov',
#  'https://keating.house.gov/',
#  'https://keating.house.gov/',
#  'https://keller.house.gov',
#  'https://keller.house.gov',
#  'https://kelly.house.gov',
#  'https://kelly.house.gov',
#  'https://kevinbrady.house.gov/',
#  'https://kevinbrady.house.gov/',
#  'https://kevinmccarthy.house.gov/',
#  'https://kevinmccarthy.house.gov/',
#  'https://khanna.house.gov',
#  'https://khanna.house.gov',
#  'https://kilmer.house.gov',
#  'https://kilmer.house.gov',
#  'https://kim.house.gov/',
#  'https://kim.house.gov/',
#  'https://kind.house.gov/',
#  'https://kind.house.gov/',
#  'https://kinzinger.house.gov/',
#  'https://kinzinger.house.gov/',
#  'https://kirkpatrick.house.gov/',
#  'https://kirkpatrick.house.gov/',
#  'https://krishnamoorthi.house.gov',
#  'https://krishnamoorthi.house.gov',
#  'https://kuster.house.gov',
#  'https://kuster.house.gov',
#  'https://kustoff.house.gov',
#  'https://kustoff.house.gov',
#  'https://lahood.house.gov/',
#  'https://lahood.house.gov/',
#  'https://lamalfa.house.gov',
#  'https://lamalfa.house.gov',
#  'https://lamb.house.gov',
#  'https://lamb.house.gov',
#  'https://lamborn.house.gov/',
#  'https://lamborn.house.gov/',
#  'https://langevin.house.gov',
#  'https://langevin.house.gov',
#  'https://larsen.house.gov',
#  'https://larsen.house.gov',
#  'https://larson.house.gov/',
#  'https://larson.house.gov/',
#  'https://latta.house.gov/',
#  'https://latta.house.gov/',
#  'https://laturner.house.gov',
#  'https://laturner.house.gov',
#  'https://lawrence.house.gov/',
#  'https://lawrence.house.gov/',
#  'https://lawson.house.gov',
#  'https://lawson.house.gov',
#  'https://lee.house.gov/',
#  'https://lee.house.gov/',
#  'https://lesko.house.gov',
#  'https://lesko.house.gov',
#  'https://lieu.house.gov/',
#  'https://lieu.house.gov/',
#  'https://lindasanchez.house.gov/',
#  'https://lindasanchez.house.gov/',
#  'https://lofgren.house.gov/',
#  'https://lofgren.house.gov/',
#  'https://long.house.gov/',
#  'https://long.house.gov/',
#  'https://loudermilk.house.gov',
#  'https://loudermilk.house.gov',
#  'https://lowenthal.house.gov',
#  'https://lowenthal.house.gov',
#  'https://lucas.house.gov',
#  'https://lucas.house.gov',
#  'https://luetkemeyer.house.gov/',
#  'https://luetkemeyer.house.gov/',
#  'https://luria.house.gov',
#  'https://luria.house.gov',
#  'https://lynch.house.gov/',
#  'https://lynch.house.gov/',
#  'https://mace.house.gov',
#  'https://mace.house.gov',
#  'https://malinowski.house.gov/',
#  'https://malinowski.house.gov/',
#  'https://malliotakis.house.gov',
#  'https://malliotakis.house.gov',
#  'https://maloney.house.gov/',
#  'https://maloney.house.gov/',
#  'https://mann.house.gov',
#  'https://mann.house.gov',
#  'https://manning.house.gov',
#  'https://manning.house.gov',
#  'https://mariodiazbalart.house.gov/',
#  'https://mariodiazbalart.house.gov/',
#  'https://markgreen.house.gov/',
#  'https://markgreen.house.gov/',
#  'https://marymiller.house.gov',
#  'https://marymiller.house.gov',
#  'https://massie.house.gov',
#  'https://massie.house.gov',
#  'https://mast.house.gov',
#  'https://mast.house.gov',
#  'https://matsui.house.gov',
#  'https://matsui.house.gov',
#  'https://mcbath.house.gov',
#  'https://mcbath.house.gov',
#  'https://mccaul.house.gov',
#  'https://mccaul.house.gov',
#  'https://mcclain.house.gov',
#  'https://mcclain.house.gov',
#  'https://mcclintock.house.gov/',
#  'https://mcclintock.house.gov/',
#  'https://mccollum.house.gov',
#  'https://mccollum.house.gov',
#  'https://mceachin.house.gov',
#  'https://mceachin.house.gov',
#  'https://mcgovern.house.gov/',
#  'https://mcgovern.house.gov/',
#  'https://mchenry.house.gov',
#  'https://mchenry.house.gov',
#  'https://mckinley.house.gov/',
#  'https://mckinley.house.gov/',
#  'https://mcmorris.house.gov/',
#  'https://mcmorris.house.gov/',
#  'https://mcnerney.house.gov/',
#  'https://mcnerney.house.gov/',
#  'https://meeks.house.gov',
#  'https://meeks.house.gov',
#  'https://meijer.house.gov',
#  'https://meijer.house.gov',
#  'https://meng.house.gov',
#  'https://meng.house.gov',
#  'https://meuser.house.gov',
#  'https://meuser.house.gov',
#  'https://mfume.house.gov/',
#  'https://mfume.house.gov/',
#  'https://mikegarcia.house.gov/',
#  'https://mikegarcia.house.gov/',
#  'https://mikejohnson.house.gov',
#  'https://mikejohnson.house.gov',
#  'https://mikelevin.house.gov',
#  'https://mikelevin.house.gov',
#  'https://mikerogers.house.gov/',
#  'https://mikerogers.house.gov/',
#  'https://mikethompson.house.gov/',
#  'https://mikethompson.house.gov/',
#  'https://miller.house.gov/',
#  'https://miller.house.gov/',
#  'https://millermeeks.house.gov/',
#  'https://millermeeks.house.gov/',
#  'https://moolenaar.house.gov/',
#  'https://moolenaar.house.gov/',
#  'https://mooney.house.gov/',
#  'https://mooney.house.gov/',
#  'https://morelle.house.gov',
#  'https://morelle.house.gov',
#  'https://morgangriffith.house.gov/',
#  'https://morgangriffith.house.gov/',
#  'https://moulton.house.gov/',
#  'https://moulton.house.gov/',
#  'https://mrvan.house.gov',
#  'https://mrvan.house.gov',
#  'https://mullin.house.gov',
#  'https://mullin.house.gov',
#  'https://murphy.house.gov',
#  'https://murphy.house.gov',
#  'https://nadler.house.gov',
#  'https://nadler.house.gov',
#  'https://napolitano.house.gov/',
#  'https://napolitano.house.gov/',
#  'https://neal.house.gov/',
#  'https://neal.house.gov/',
#  'https://neguse.house.gov/',
#  'https://neguse.house.gov/',
#  'https://nehls.house.gov',
#  'https://nehls.house.gov',
#  'https://newhouse.house.gov',
#  'https://newhouse.house.gov',
#  'https://newman.house.gov',
#  'https://newman.house.gov',
#  'https://nikemawilliams.house.gov',
#  'https://nikemawilliams.house.gov',
#  'https://norcross.house.gov',
#  'https://norcross.house.gov',
#  'https://norman.house.gov',
#  'https://norman.house.gov',
#  'https://norton.house.gov/',
#  'https://norton.house.gov/',
#  'https://nunes.house.gov/',
#  'https://nunes.house.gov/',
#  'https://obernolte.house.gov',
#  'https://obernolte.house.gov',
#  'https://ocasio-cortez.house.gov/',
#  'https://ocasio-cortez.house.gov/',
#  'https://ohalleran.house.gov',
#  'https://ohalleran.house.gov',
#  'https://omar.house.gov/',
#  'https://omar.house.gov/',
#  'https://owens.house.gov',
#  'https://owens.house.gov',
#  'https://palazzo.house.gov/',
#  'https://palazzo.house.gov/',
#  'https://pallone.house.gov',
#  'https://pallone.house.gov',
#  'https://palmer.house.gov/',
#  'https://palmer.house.gov/',
#  'https://panetta.house.gov',
#  'https://panetta.house.gov',
#  'https://pappas.house.gov',
#  'https://pappas.house.gov',
#  'https://pascrell.house.gov/',
#  'https://pascrell.house.gov/',
#  'https://payne.house.gov',
#  'https://payne.house.gov',
#  'https://pelosi.house.gov/',
#  'https://pelosi.house.gov/',
#  'https://pence.house.gov/',
#  'https://pence.house.gov/',
#  'https://perlmutter.house.gov/',
#  'https://perlmutter.house.gov/',
#  'https://perry.house.gov/',
#  'https://perry.house.gov/',
#  'https://pfluger.house.gov',
#  'https://pfluger.house.gov',
#  'https://phillips.house.gov/',
#  'https://phillips.house.gov/',
#  'https://pingree.house.gov/',
#  'https://pingree.house.gov/',
#  'https://plaskett.house.gov/',
#  'https://plaskett.house.gov/',
#  'https://pocan.house.gov',
#  'https://pocan.house.gov',
#  'https://porter.house.gov/',
#  'https://porter.house.gov/',
#  'https://posey.house.gov/',
#  'https://posey.house.gov/',
#  'https://pressley.house.gov',
#  'https://pressley.house.gov',
#  'https://price.house.gov/',
#  'https://price.house.gov/',
#  'https://quigley.house.gov/',
#  'https://quigley.house.gov/',
#  'https://radewagen.house.gov/',
#  'https://radewagen.house.gov/',
#  'https://raskin.house.gov',
#  'https://raskin.house.gov',
#  'https://reed.house.gov/',
#  'https://reed.house.gov/',
#  'https://reschenthaler.house.gov/',
#  'https://reschenthaler.house.gov/',
#  'https://rice.house.gov',
#  'https://rice.house.gov',
#  'https://ritchietorres.house.gov',
#  'https://ritchietorres.house.gov',
#  'https://robinkelly.house.gov/',
#  'https://robinkelly.house.gov/',
#  'https://rodneydavis.house.gov',
#  'https://rodneydavis.house.gov',
#  'https://rosendale.house.gov',
#  'https://rosendale.house.gov',
#  'https://ross.house.gov',
#  'https://ross.house.gov',
#  'https://rouzer.house.gov/',
#  'https://rouzer.house.gov/',
#  'https://roy.house.gov',
#  'https://roy.house.gov',
#  'https://roybal-allard.house.gov',
#  'https://roybal-allard.house.gov',
#  'https://rubengallego.house.gov/',
#  'https://rubengallego.house.gov/',
#  'https://ruiz.house.gov',
#  'https://ruiz.house.gov',
#  'https://ruppersberger.house.gov',
#  'https://ruppersberger.house.gov',
#  'https://rush.house.gov',
#  'https://rush.house.gov',
#  'https://rutherford.house.gov',
#  'https://rutherford.house.gov',
#  'https://sablan.house.gov/',
#  'https://sablan.house.gov/',
#  'https://salazar.house.gov',
#  'https://salazar.house.gov',
#  'https://sannicolas.house.gov',
#  'https://sannicolas.house.gov',
#  'https://sarajacobs.house.gov',
#  'https://sarajacobs.house.gov',
#  'https://sarbanes.house.gov/',
#  'https://sarbanes.house.gov/',
#  'https://scalise.house.gov/',
#  'https://scalise.house.gov/',
#  'https://scanlon.house.gov/',
#  'https://scanlon.house.gov/',
#  'https://schakowsky.house.gov',
#  'https://schakowsky.house.gov',
#  'https://schiff.house.gov/',
#  'https://schiff.house.gov/',
#  'https://schneider.house.gov',
#  'https://schneider.house.gov',
#  'https://schrader.house.gov/',
#  'https://schrader.house.gov/',
#  'https://schrier.house.gov',
#  'https://schrier.house.gov',
#  'https://schweikert.house.gov/',
#  'https://schweikert.house.gov/',
#  'https://scottpeters.house.gov',
#  'https://scottpeters.house.gov',
#  'https://seanmaloney.house.gov',
#  'https://seanmaloney.house.gov',
#  'https://sessions.house.gov',
#  'https://sessions.house.gov',
#  'https://sewell.house.gov/',
#  'https://sewell.house.gov/',
#  'https://sherman.house.gov',
#  'https://sherman.house.gov',
#  'https://sherrill.house.gov/',
#  'https://sherrill.house.gov/',
#  'https://simpson.house.gov',
#  'https://simpson.house.gov',
#  'https://sires.house.gov',
#  'https://sires.house.gov',
#  'https://slotkin.house.gov/',
#  'https://slotkin.house.gov/',
#  'https://smucker.house.gov/',
#  'https://smucker.house.gov/',
#  'https://soto.house.gov',
#  'https://soto.house.gov',
#  'https://spanberger.house.gov',
#  'https://spanberger.house.gov',
#  'https://spartz.house.gov',
#  'https://spartz.house.gov',
#  'https://speier.house.gov/',
#  'https://speier.house.gov/',
#  'https://stanton.house.gov/',
#  'https://stanton.house.gov/',
#  'https://stauber.house.gov',
#  'https://stauber.house.gov',
#  'https://steel.house.gov',
#  'https://steel.house.gov',
#  'https://stefanik.house.gov/',
#  'https://stefanik.house.gov/',
#  'https://steil.house.gov',
#  'https://steil.house.gov',
#  'https://steube.house.gov/',
#  'https://steube.house.gov/',
#  'https://stevens.house.gov/',
#  'https://stevens.house.gov/',
#  'https://stewart.house.gov',
#  'https://stewart.house.gov',
#  'https://stivers.house.gov/',
#  'https://stivers.house.gov/',
#  'https://strickland.house.gov',
#  'https://strickland.house.gov',
#  'https://suozzi.house.gov',
#  'https://suozzi.house.gov',
#  'https://susielee.house.gov',
#  'https://susielee.house.gov',
#  'https://swalwell.house.gov',
#  'https://swalwell.house.gov',
#  'https://sylviagarcia.house.gov/',
#  'https://sylviagarcia.house.gov/',
#  'https://takano.house.gov',
#  'https://takano.house.gov',
#  'https://teddeutch.house.gov/',
#  'https://teddeutch.house.gov/',
#  'https://thompson.house.gov',
#  'https://thompson.house.gov',
#  'https://tiffany.house.gov/',
#  'https://tiffany.house.gov/',
#  'https://timmons.house.gov/',
#  'https://timmons.house.gov/',
#  'https://timryan.house.gov/',
#  'https://timryan.house.gov/',
#  'https://titus.house.gov/',
#  'https://titus.house.gov/',
#  'https://tlaib.house.gov/',
#  'https://tlaib.house.gov/',
#  'https://tonko.house.gov/',
#  'https://tonko.house.gov/',
#  'https://torres.house.gov/',
#  'https://torres.house.gov/',
#  'https://trahan.house.gov',
#  'https://trahan.house.gov',
#  'https://trentkelly.house.gov/',
#  'https://trentkelly.house.gov/',
#  'https://trone.house.gov',
#  'https://trone.house.gov',
#  'https://turner.house.gov/',
#  'https://turner.house.gov/',
#  'https://underwood.house.gov/',
#  'https://underwood.house.gov/',
#  'https://upton.house.gov',
#  'https://upton.house.gov',
#  'https://valadao.house.gov',
#  'https://valadao.house.gov',
#  'https://vandrew.house.gov',
#  'https://vandrew.house.gov',
#  'https://vanduyne.house.gov',
#  'https://vanduyne.house.gov',
#  'https://vantaylor.house.gov/',
#  'https://vantaylor.house.gov/',
#  'https://vargas.house.gov',
#  'https://vargas.house.gov',
#  'https://veasey.house.gov',
#  'https://veasey.house.gov',
#  'https://vela.house.gov',
#  'https://vela.house.gov',
#  'https://velazquez.house.gov',
#  'https://velazquez.house.gov',
#  'https://wagner.house.gov',
#  'https://wagner.house.gov',
#  'https://walberg.house.gov/',
#  'https://walberg.house.gov/',
#  'https://walorski.house.gov',
#  'https://walorski.house.gov',
#  'https://waltz.house.gov',
#  'https://waltz.house.gov',
#  'https://wassermanschultz.house.gov/',
#  'https://wassermanschultz.house.gov/',
#  'https://waters.house.gov',
#  'https://waters.house.gov',
#  'https://watsoncoleman.house.gov/',
#  'https://watsoncoleman.house.gov/',
#  'https://weber.house.gov',
#  'https://weber.house.gov',
#  'https://webster.house.gov/',
#  'https://webster.house.gov/',
#  'https://welch.house.gov/',
#  'https://welch.house.gov/',
#  'https://wenstrup.house.gov',
#  'https://wenstrup.house.gov',
#  'https://westerman.house.gov/',
#  'https://westerman.house.gov/',
#  'https://wexton.house.gov/',
#  'https://wexton.house.gov/',
#  'https://wild.house.gov',
#  'https://wild.house.gov',
#  'https://williams.house.gov',
#  'https://williams.house.gov',
#  'https://wilson.house.gov/',
#  'https://wilson.house.gov/',
#  'https://wittman.house.gov/',
#  'https://wittman.house.gov/',
#  'https://womack.house.gov/',
#  'https://womack.house.gov/',
#  'https://wright.house.gov/',
#  'https://wright.house.gov/',
#  'https://yarmuth.house.gov/',
#  'https://yarmuth.house.gov/',
#  'https://youngkim.house.gov',
#  'https://youngkim.house.gov',
#  'https://zeldin.house.gov/',
#  'https://zeldin.house.gov/']

# %%
good_urls = list(set(good_urls))
good_urls
# Out:
# ['https://johnrose.house.gov/',
#  'https://seanmaloney.house.gov',
#  'https://delbene.house.gov',
#  'https://hartzler.house.gov/',
#  'https://spartz.house.gov',
#  'https://bacon.house.gov',
#  'https://kahele.house.gov',
#  'https://owens.house.gov',
#  'https://lynch.house.gov/',
#  'https://sarbanes.house.gov/',
#  'https://kind.house.gov/',
#  'https://issa.house.gov',
#  'https://tlaib.house.gov/',
#  'https://murphy.house.gov',
#  'https://norcross.house.gov',
#  'https://waltz.house.gov',
#  'https://halrogers.house.gov/',
#  'https://valadao.house.gov',
#  'https://gosar.house.gov/',
#  'https://gaetz.house.gov',
#  'https://stefanik.house.gov/',
#  'https://connolly.house.gov/',
#  'https://sylviagarcia.house.gov/',
#  'https://bost.house.gov/',
#  'https://radewagen.house.gov/',
#  'https://espaillat.house.gov',
#  'https://cheney.house.gov',
#  'https://salazar.house.gov',
#  'https://mann.house.gov',
#  'https://benniethompson.house.gov/',
#  'https://buchanan.house.gov/',
#  'https://bilirakis.house.gov/',
#  'https://garbarino.house.gov',
#  'https://luetkemeyer.house.gov/',
#  'https://swalwell.house.gov',
#  'https://khanna.house.gov',
#  'https://mfume.house.gov/',
#  'https://watsoncoleman.house.gov/',
#  'https://meeks.house.gov',
#  'https://frankel.house.gov',
#  'https://trentkelly.house.gov/',
#  'https://bourdeaux.house.gov',
#  'https://huffman.house.gov',
#  'https://harris.house.gov/',
#  'https://feenstra.house.gov',
#  'https://neguse.house.gov/',
#  'https://steel.house.gov',
#  'https://rice.house.gov',
#  'https://dunn.house.gov',
#  'https://doyle.house.gov',
#  'https://bush.house.gov',
#  'https://clarke.house.gov/',
#  'https://gallagher.house.gov',
#  'https://kirkpatrick.house.gov/',
#  'https://lofgren.house.gov/',
#  'https://ohalleran.house.gov',
#  'https://walberg.house.gov/',
#  'https://bobbyscott.house.gov',
#  'https://meng.house.gov',
#  'https://delgado.house.gov',
#  'https://napolitano.house.gov/',
#  'https://chrissmith.house.gov/',
#  'https://veasey.house.gov',
#  'https://carson.house.gov/',
#  'https://mchenry.house.gov',
#  'https://vantaylor.house.gov/',
#  'https://stevens.house.gov/',
#  'https://garamendi.house.gov/',
#  'https://vandrew.house.gov',
#  'https://payne.house.gov',
#  'https://vanduyne.house.gov',
#  'https://lahood.house.gov/',
#  'https://escobar.house.gov',
#  'https://adams.house.gov',
#  'https://maloney.house.gov/',
#  'https://joyce.house.gov',
#  'https://susielee.house.gov',
#  'https://demings.house.gov',
#  'https://rouzer.house.gov/',
#  'https://schrader.house.gov/',
#  'https://bergman.house.gov',
#  'https://gregmurphy.house.gov',
#  'https://chabot.house.gov/',
#  'https://billjohnson.house.gov/',
#  'https://crow.house.gov/',
#  'https://fischbach.house.gov',
#  'https://harder.house.gov/',
#  'https://buck.house.gov/',
#  'https://ferguson.house.gov',
#  'https://eshoo.house.gov/',
#  'https://mccollum.house.gov',
#  'https://wassermanschultz.house.gov/',
#  'https://brooks.house.gov/',
#  'https://houlahan.house.gov/',
#  'https://juliabrownley.house.gov',
#  'https://scottpeters.house.gov',
#  'https://sablan.house.gov/',
#  'https://algreen.house.gov',
#  'https://stivers.house.gov/',
#  'https://auchincloss.house.gov',
#  'https://webster.house.gov/',
#  'https://williams.house.gov',
#  'https://bowman.house.gov',
#  'https://kustoff.house.gov',
#  'https://laturner.house.gov',
#  'https://mace.house.gov',
#  'https://pocan.house.gov',
#  'https://pingree.house.gov/',
#  'https://allred.house.gov/',
#  'https://guthrie.house.gov/',
#  'https://banks.house.gov',
#  'https://price.house.gov/',
#  'https://malliotakis.house.gov',
#  'https://underwood.house.gov/',
#  'https://cleaver.house.gov',
#  'https://hill.house.gov/',
#  'https://gottheimer.house.gov',
#  'https://torres.house.gov/',
#  'https://speier.house.gov/',
#  'https://gooden.house.gov',
#  'https://nikemawilliams.house.gov',
#  'https://yarmuth.house.gov/',
#  'https://baird.house.gov/',
#  'https://mceachin.house.gov',
#  'https://weber.house.gov',
#  'https://allen.house.gov',
#  'https://danbishop.house.gov',
#  'https://axne.house.gov/',
#  'https://mikejohnson.house.gov',
#  'https://pallone.house.gov',
#  'https://carbajal.house.gov',
#  'https://himes.house.gov/',
#  'https://scanlon.house.gov/',
#  'https://westerman.house.gov/',
#  'https://moolenaar.house.gov/',
#  'https://mcmorris.house.gov/',
#  'https://cartwright.house.gov',
#  'https://welch.house.gov/',
#  'https://wagner.house.gov',
#  'https://butterfield.house.gov',
#  'https://boyle.house.gov/',
#  'https://lawson.house.gov',
#  'https://davids.house.gov/',
#  'https://castor.house.gov/',
#  'https://hankjohnson.house.gov/',
#  'https://mrvan.house.gov',
#  'https://dankildee.house.gov',
#  'https://rosendale.house.gov',
#  'https://graves.house.gov/',
#  'https://sarajacobs.house.gov',
#  'https://raskin.house.gov',
#  'https://sessions.house.gov',
#  'https://clayhiggins.house.gov',
#  'https://morgangriffith.house.gov/',
#  'https://tiffany.house.gov/',
#  'https://degette.house.gov',
#  'https://fallon.house.gov',
#  'https://youngkim.house.gov',
#  'https://pascrell.house.gov/',
#  'https://thompson.house.gov',
#  'https://golden.house.gov',
#  'https://manning.house.gov',
#  'https://rush.house.gov',
#  'https://lamalfa.house.gov',
#  'https://kaygranger.house.gov',
#  'https://ebjohnson.house.gov',
#  'https://vargas.house.gov',
#  'https://bentz.house.gov',
#  'https://costa.house.gov/',
#  'https://dean.house.gov',
#  'https://larson.house.gov/',
#  'https://wright.house.gov/',
#  'https://bishop.house.gov/',
#  'https://newman.house.gov',
#  'https://zeldin.house.gov/',
#  'https://larsen.house.gov',
#  'https://stewart.house.gov',
#  'https://joewilson.house.gov/',
#  'https://bonamici.house.gov',
#  'https://latta.house.gov/',
#  'https://nadler.house.gov',
#  'https://babin.house.gov',
#  'https://aguilar.house.gov/',
#  'https://pfluger.house.gov',
#  'https://kevinbrady.house.gov/',
#  'https://matsui.house.gov',
#  'https://crist.house.gov',
#  'https://greene.house.gov',
#  'https://boebert.house.gov',
#  'https://hice.house.gov/',
#  'https://desaulnier.house.gov/',
#  'https://cloud.house.gov',
#  'https://malinowski.house.gov/',
#  'https://ruiz.house.gov',
#  'https://fortenberry.house.gov/',
#  'https://burchett.house.gov',
#  'https://fleischmann.house.gov/',
#  'https://rutherford.house.gov',
#  'https://newhouse.house.gov',
#  'https://fitzgerald.house.gov',
#  'https://ross.house.gov',
#  'https://markgreen.house.gov/',
#  'https://timryan.house.gov/',
#  'https://steil.house.gov',
#  'https://cuellar.house.gov/',
#  'https://schweikert.house.gov/',
#  'https://kelly.house.gov',
#  'https://teddeutch.house.gov/',
#  'https://estes.house.gov/',
#  'https://posey.house.gov/',
#  'https://horsford.house.gov',
#  'https://pelosi.house.gov/',
#  'https://rubengallego.house.gov/',
#  'https://bustos.house.gov',
#  'https://mcclain.house.gov',
#  'https://gohmert.house.gov/',
#  'https://bass.house.gov/',
#  'https://jasonsmith.house.gov',
#  'https://lamborn.house.gov/',
#  'https://gonzales.house.gov',
#  'https://tonko.house.gov/',
#  'https://marymiller.house.gov',
#  'https://craig.house.gov',
#  'https://sires.house.gov',
#  'https://courtney.house.gov/',
#  'https://debbiedingell.house.gov/',
#  'https://pressley.house.gov',
#  'https://ritchietorres.house.gov',
#  'https://cicilline.house.gov/',
#  'https://donyoung.house.gov/',
#  'https://wittman.house.gov/',
#  'https://hinson.house.gov',
#  'https://blumenauer.house.gov/',
#  'https://kinzinger.house.gov/',
#  'https://hudson.house.gov',
#  'https://calvert.house.gov/',
#  'https://jones.house.gov',
#  'https://waters.house.gov',
#  'https://haaland.house.gov/',
#  'https://lamb.house.gov',
#  'https://lesko.house.gov',
#  'https://norton.house.gov/',
#  'https://correa.house.gov',
#  'https://mooney.house.gov/',
#  'https://sherrill.house.gov/',
#  'https://crawford.house.gov/',
#  'https://omar.house.gov/',
#  'https://lucas.house.gov',
#  'https://budd.house.gov',
#  'https://fernandez.house.gov',
#  'https://foxx.house.gov/',
#  'https://mikegarcia.house.gov/',
#  'https://donalds.house.gov',
#  'https://langevin.house.gov',
#  'https://blakemoore.house.gov',
#  'https://hern.house.gov',
#  'https://cohen.house.gov/',
#  'https://grothman.house.gov',
#  'https://chu.house.gov/',
#  'https://smucker.house.gov/',
#  'https://spanberger.house.gov',
#  'https://kim.house.gov/',
#  'https://krishnamoorthi.house.gov',
#  'https://adriansmith.house.gov/',
#  'https://pence.house.gov/',
#  'https://gomez.house.gov/',
#  'https://jacksonlee.house.gov/',
#  'https://sherman.house.gov',
#  'https://beyer.house.gov',
#  'https://jeffries.house.gov',
#  'https://arrington.house.gov',
#  'https://scalise.house.gov/',
#  'https://pappas.house.gov',
#  'https://miller.house.gov/',
#  'https://suozzi.house.gov',
#  'https://armstrong.house.gov',
#  'https://jhb.house.gov/',
#  'https://meuser.house.gov',
#  'https://panetta.house.gov',
#  'https://alceehastings.house.gov/',
#  'https://loudermilk.house.gov',
#  'https://fulcher.house.gov/',
#  'https://chuygarcia.house.gov/',
#  'https://mcnerney.house.gov/',
#  'https://cawthorn.house.gov',
#  'https://soto.house.gov',
#  'https://davis.house.gov',
#  'https://anthonybrown.house.gov',
#  'https://austinscott.house.gov/',
#  'https://jacobs.house.gov',
#  'https://neal.house.gov/',
#  'https://quigley.house.gov/',
#  'https://desjarlais.house.gov/',
#  'https://meijer.house.gov',
#  'https://vela.house.gov',
#  'https://aderholt.house.gov/',
#  'https://mast.house.gov',
#  'https://massie.house.gov',
#  'https://clyde.house.gov',
#  'https://barragan.house.gov',
#  'https://lawrence.house.gov/',
#  'https://davidson.house.gov/',
#  'https://evans.house.gov/',
#  'https://palmer.house.gov/',
#  'https://guest.house.gov',
#  'https://cooper.house.gov/',
#  'https://katko.house.gov/',
#  'https://roybal-allard.house.gov',
#  'https://buddycarter.house.gov/',
#  'https://delauro.house.gov/',
#  'https://doggett.house.gov',
#  'https://lieu.house.gov/',
#  'https://schakowsky.house.gov',
#  'https://keating.house.gov/',
#  'https://ruppersberger.house.gov',
#  'https://harshbarger.house.gov',
#  'https://hoyer.house.gov/',
#  'https://upton.house.gov',
#  'https://defazio.house.gov/',
#  'https://nehls.house.gov',
#  'https://jordan.house.gov/',
#  'https://mikelevin.house.gov',
#  'https://moulton.house.gov/',
#  'https://takano.house.gov',
#  'https://jackson.house.gov',
#  'https://trahan.house.gov',
#  'https://hollingsworth.house.gov',
#  'https://trone.house.gov',
#  'https://reschenthaler.house.gov/',
#  'https://long.house.gov/',
#  'https://jayapal.house.gov',
#  'https://mikethompson.house.gov/',
#  'https://case.house.gov/',
#  'https://andylevin.house.gov/',
#  'https://stanton.house.gov/',
#  'https://sewell.house.gov/',
#  'https://gwenmoore.house.gov',
#  'https://bluntrochester.house.gov',
#  'https://porter.house.gov/',
#  'https://walorski.house.gov',
#  'https://kilmer.house.gov',
#  'https://adamsmith.house.gov/',
#  'https://garretgraves.house.gov/',
#  'https://gonzalez.house.gov',
#  'https://mariodiazbalart.house.gov/',
#  'https://carl.house.gov',
#  'https://mullin.house.gov',
#  'https://bera.house.gov',
#  'https://cammack.house.gov',
#  'https://palazzo.house.gov/',
#  'https://titus.house.gov/',
#  'https://herrell.house.gov',
#  'https://fudge.house.gov/',
#  'https://kaptur.house.gov/',
#  'https://simpson.house.gov',
#  'https://wexton.house.gov/',
#  'https://mckinley.house.gov/',
#  'https://schiff.house.gov/',
#  'https://bucshon.house.gov/',
#  'https://lowenthal.house.gov',
#  'https://carter.house.gov/',
#  'https://bice.house.gov',
#  'https://crenshaw.house.gov/',
#  'https://keller.house.gov',
#  'https://mccaul.house.gov',
#  'https://mcbath.house.gov',
#  'https://robinkelly.house.gov/',
#  'https://millermeeks.house.gov/',
#  'https://plaskett.house.gov/',
#  'https://wilson.house.gov/',
#  'https://reed.house.gov/',
#  'https://kuster.house.gov',
#  'https://emmer.house.gov/',
#  'https://barr.house.gov/',
#  'https://morelle.house.gov',
#  'https://cole.house.gov',
#  'https://curtis.house.gov/',
#  'https://mcclintock.house.gov/',
#  'https://dustyjohnson.house.gov/',
#  'https://grijalva.house.gov/',
#  'https://sannicolas.house.gov',
#  'https://schneider.house.gov',
#  'https://slotkin.house.gov/',
#  'https://kevinmccarthy.house.gov/',
#  'https://hayes.house.gov',
#  'https://johnjoyce.house.gov/',
#  'https://higgins.house.gov',
#  'https://jeffduncan.house.gov/',
#  'https://schrier.house.gov',
#  'https://casten.house.gov',
#  'https://rodneydavis.house.gov',
#  'https://norman.house.gov',
#  'https://fletcher.house.gov',
#  'https://steube.house.gov/',
#  'https://fitzpatrick.house.gov/',
#  'https://gonzalez-colon.house.gov',
#  'https://amodei.house.gov',
#  'https://huizenga.house.gov/',
#  'https://cline.house.gov',
#  'https://cardenas.house.gov',
#  'https://lee.house.gov/',
#  'https://lindasanchez.house.gov/',
#  'https://nunes.house.gov/',
#  'https://anthonygonzalez.house.gov',
#  'https://franklin.house.gov',
#  'https://wild.house.gov',
#  'https://balderson.house.gov',
#  'https://clyburn.house.gov/',
#  'https://kathleenrice.house.gov',
#  'https://comer.house.gov/',
#  'https://luria.house.gov',
#  'https://stauber.house.gov',
#  'https://velazquez.house.gov',
#  'https://roy.house.gov',
#  'https://turner.house.gov/',
#  'https://good.house.gov',
#  'https://barrymoore.house.gov',
#  'https://perlmutter.house.gov/',
#  'https://beatty.house.gov',
#  'https://biggs.house.gov',
#  'https://davidscott.house.gov/',
#  'https://obernolte.house.gov',
#  'https://perry.house.gov/',
#  'https://burgess.house.gov/',
#  'https://hagedorn.house.gov/',
#  'https://foster.house.gov',
#  'https://castro.house.gov',
#  'https://phillips.house.gov/',
#  'https://gimenez.house.gov',
#  'https://wenstrup.house.gov',
#  'https://gibbs.house.gov/',
#  'https://womack.house.gov/',
#  'https://timmons.house.gov/',
#  'https://strickland.house.gov',
#  'https://ocasio-cortez.house.gov/',
#  'https://mcgovern.house.gov/',
#  'https://mikerogers.house.gov/']

# %%
len(good_urls)
# Out:
# 437

# %%
html = requests.get('https://jayapal.house.gov').text
soup = BeautifulSoup(html, 'html5lib')
links = {a['href'] for a in soup('a') if 'press releases' in a.text.lower()}
links
# Out:
# {'https://jayapal.house.gov/category/news/',
#  'https://jayapal.house.gov/category/press-releases/'}

# %%
from typing import Dict, Set

# %%
press_releases: Dict[str, Set[str]] = {}

# %%
for house_url in good_urls:
    html = requests.get(house_url).text
    soup = BeautifulSoup(html, 'html5lib')
    pr_links = {a['href'] for a in soup('a') if 'press releases' in a.text.lower()}
    print(f"{house_url}: {pr_links}")
    press_releases[house_url] = pr_links
# Out:
# https://johnrose.house.gov/: {'/media/press-releases'}
# https://seanmaloney.house.gov: set()
# https://delbene.house.gov: {'/news/documentquery.aspx?DocumentTypeID=27'}
# https://hartzler.house.gov/: {'/media-center/press-releases'}
# https://spartz.house.gov: {'/media/press-releases'}
# https://bacon.house.gov: {'/news/documentquery.aspx?DocumentTypeID=27'}
# https://kahele.house.gov: {'/media/press-releases'}
# https://owens.house.gov: {'/media/press-releases'}
# https://lynch.house.gov/: {'/press-releases'}
# https://sarbanes.house.gov/: {'/media-center/press-releases'}
# https://kind.house.gov/: {'/media-center/press-releases'}
# https://issa.house.gov: {'/media/press-releases'}
# https://tlaib.house.gov/: {'/media/press-releases'}
# https://murphy.house.gov: {'/news/documentquery.aspx?DocumentTypeID=27'}
# https://norcross.house.gov: set()
# https://waltz.house.gov: {'/news/documentquery.aspx?DocumentTypeID=27'}
# https://halrogers.house.gov/: {'/press-releases'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-138-e4fccf2d179c> in <module>
#       1 for house_url in good_urls:
#       2     html = requests.get(house_url).text
# ----> 3     soup = BeautifulSoup(html, 'html5lib')
#       4     pr_links = {a['href'] for a in soup('a') if 'press releases' in a.text.lower()}
#       5     print(f"{house_url}: {pr_links}")
#
# ~/anaconda3/lib/python3.8/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     346             self.reset()
#     347             try:
# --> 348                 self._feed()
#     349                 success = True
#     350                 break
#
# ~/anaconda3/lib/python3.8/site-packages/bs4/__init__.py in _feed(self)
#     432         self.builder.reset()
#     433
# --> 434         self.builder.feed(self.markup)
#     435         # Close out any unfinished strings and close all the open tags.
#     436         self.endData()
#
# ~/anaconda3/lib/python3.8/site-packages/bs4/builder/_html5lib.py in feed(self, markup)
#      85             else:
#      86                 extra_kwargs['encoding'] = self.user_specified_encoding
# ---> 87         doc = parser.parse(markup, **extra_kwargs)
#      88
#      89         # Set the character encoding detected by the tokenizer.
#
# ~/anaconda3/lib/python3.8/site-packages/html5lib/html5parser.py in parse(self, stream, *args, **kwargs)
#     282
#     283         """
# --> 284         self._parse(stream, False, None, *args, **kwargs)
#     285         return self.tree.getDocument()
#     286
#
# ~/anaconda3/lib/python3.8/site-packages/html5lib/html5parser.py in _parse(self, stream, innerHTML, container, scripting, **kwargs)
#     131
#     132         try:
# --> 133             self.mainLoop()
#     134         except _ReparseException:
#     135             self.reset()
#
# ~/anaconda3/lib/python3.8/site-packages/html5lib/html5parser.py in mainLoop(self)
#     238                         new_token = phase.processSpaceCharacters(new_token)
#     239                     elif type == StartTagToken:
# --> 240                         new_token = phase.processStartTag(new_token)
#     241                     elif type == EndTagToken:
#     242                         new_token = phase.processEndTag(new_token)
#
# ~/anaconda3/lib/python3.8/site-packages/html5lib/html5parser.py in processStartTag(self, token)
#     467                     # this makes the eviction policy random on Py < 3.7 and FIFO >= 3.7
#     468                     self.__startTagCache.pop(next(iter(self.__startTagCache)))
# --> 469             return func(token)
#     470
#     471         def startTagHtml(self, token):
#
# ~/anaconda3/lib/python3.8/site-packages/html5lib/html5parser.py in startTagCloseP(self, token)
#    1040
#    1041         def startTagCloseP(self, token):
# -> 1042             if self.tree.elementInScope("p", variant="button"):
#    1043                 self.endTagP(impliedTagToken("p"))
#    1044             self.tree.insertElement(token)
#
# ~/anaconda3/lib/python3.8/site-packages/html5lib/treebuilders/base.py in elementInScope(self, target, variant)
#     211             elif not exactNode and node.nameTuple == target:
#     212                 return True
# --> 213             elif (invert ^ (node.nameTuple in listElements)):
#     214                 return False
#     215
#
# KeyboardInterrupt:

# %%
def paragraph_mentions(text, keyword):
    """
    Returns True if a <p> inside the text mentions {keyword}
    """
    soup = BeautifulSoup(text, 'html5lib')
    paragraphs = [p.get_text() for p in soup('p')]
    return any(keyword.lower() in paragraph.lower() for paragraph in paragraphs)

# %%
text = """<body><h1>Facebook</h1><p>Twitter</p>"""
keyword = "twitter"
assert paragraph_mentions(text, keyword)
keyword = "facebook"
assert not paragraph_mentions(text, keyword)

# %%
for house_url, pr_links in press_releases.items():
    for pr_link in pr_links:
        url = f"{house_url}/{pr_link}"
        text = requests.get(url).text
        keyword = "data"
        if paragraph_mentions(text, keyword):
            print(f"{house_url}")
            break
# Out:
# https://delbene.house.gov

# %%
# API's

# %%
import json

# %%
serialized = """{ "title":"Data Science Book", "author":"Joel Grus", "publicationYear": 2019, "topics": ["data", "science", "datascience", "data science"] }"""
serialized
# Out:
# '{ "title":"Data Science Book", "author":"Joel Grus", "publicationYear": 2019, "topics": ["data", "science", "datascience", "data science"] }'

# %%
deserialized = json.loads(serialized)
assert deserialized["publicationYear"] == 2019
assert "data science" in deserialized["topics"]

# %%
# unauthenticated API's

# %%
github_user = "mcwaage1"
endpoint = f"https://api.github.com/users/{github_user}/repos"
repos = json.loads(requests.get(endpoint).text)

# %%
endpoint
# Out:
# 'https://api.github.com/users/mcwaage1/repos'

# %%
repos
# Out:
# [{'id': 330612750,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMzA2MTI3NTA=',
#   'name': 'datascience',
#   'full_name': 'mcwaage1/datascience',
#   'private': False,
#   'owner': {'login': 'mcwaage1',
#    'id': 49893491,
#    'node_id': 'MDQ6VXNlcjQ5ODkzNDkx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49893491?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mcwaage1',
#    'html_url': 'https://github.com/mcwaage1',
#    'followers_url': 'https://api.github.com/users/mcwaage1/followers',
#    'following_url': 'https://api.github.com/users/mcwaage1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mcwaage1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mcwaage1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mcwaage1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mcwaage1/orgs',
#    'repos_url': 'https://api.github.com/users/mcwaage1/repos',
#    'events_url': 'https://api.github.com/users/mcwaage1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mcwaage1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/mcwaage1/datascience',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/mcwaage1/datascience',
#   'forks_url': 'https://api.github.com/repos/mcwaage1/datascience/forks',
#   'keys_url': 'https://api.github.com/repos/mcwaage1/datascience/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/mcwaage1/datascience/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/mcwaage1/datascience/teams',
#   'hooks_url': 'https://api.github.com/repos/mcwaage1/datascience/hooks',
#   'issue_events_url': 'https://api.github.com/repos/mcwaage1/datascience/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/mcwaage1/datascience/events',
#   'assignees_url': 'https://api.github.com/repos/mcwaage1/datascience/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/mcwaage1/datascience/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/mcwaage1/datascience/tags',
#   'blobs_url': 'https://api.github.com/repos/mcwaage1/datascience/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/mcwaage1/datascience/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/mcwaage1/datascience/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/mcwaage1/datascience/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/mcwaage1/datascience/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/mcwaage1/datascience/languages',
#   'stargazers_url': 'https://api.github.com/repos/mcwaage1/datascience/stargazers',
#   'contributors_url': 'https://api.github.com/repos/mcwaage1/datascience/contributors',
#   'subscribers_url': 'https://api.github.com/repos/mcwaage1/datascience/subscribers',
#   'subscription_url': 'https://api.github.com/repos/mcwaage1/datascience/subscription',
#   'commits_url': 'https://api.github.com/repos/mcwaage1/datascience/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/mcwaage1/datascience/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/mcwaage1/datascience/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/mcwaage1/datascience/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/mcwaage1/datascience/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/mcwaage1/datascience/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/mcwaage1/datascience/merges',
#   'archive_url': 'https://api.github.com/repos/mcwaage1/datascience/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/mcwaage1/datascience/downloads',
#   'issues_url': 'https://api.github.com/repos/mcwaage1/datascience/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/mcwaage1/datascience/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/mcwaage1/datascience/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/mcwaage1/datascience/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/mcwaage1/datascience/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/mcwaage1/datascience/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/mcwaage1/datascience/deployments',
#   'created_at': '2021-01-18T09:15:14Z',
#   'updated_at': '2021-02-04T10:48:00Z',
#   'pushed_at': '2021-02-04T10:47:58Z',
#   'git_url': 'git://github.com/mcwaage1/datascience.git',
#   'ssh_url': 'git@github.com:mcwaage1/datascience.git',
#   'clone_url': 'https://github.com/mcwaage1/datascience.git',
#   'svn_url': 'https://github.com/mcwaage1/datascience',
#   'homepage': None,
#   'size': 280,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 306531162,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMDY1MzExNjI=',
#   'name': 'django',
#   'full_name': 'mcwaage1/django',
#   'private': False,
#   'owner': {'login': 'mcwaage1',
#    'id': 49893491,
#    'node_id': 'MDQ6VXNlcjQ5ODkzNDkx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49893491?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mcwaage1',
#    'html_url': 'https://github.com/mcwaage1',
#    'followers_url': 'https://api.github.com/users/mcwaage1/followers',
#    'following_url': 'https://api.github.com/users/mcwaage1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mcwaage1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mcwaage1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mcwaage1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mcwaage1/orgs',
#    'repos_url': 'https://api.github.com/users/mcwaage1/repos',
#    'events_url': 'https://api.github.com/users/mcwaage1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mcwaage1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/mcwaage1/django',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/mcwaage1/django',
#   'forks_url': 'https://api.github.com/repos/mcwaage1/django/forks',
#   'keys_url': 'https://api.github.com/repos/mcwaage1/django/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/mcwaage1/django/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/mcwaage1/django/teams',
#   'hooks_url': 'https://api.github.com/repos/mcwaage1/django/hooks',
#   'issue_events_url': 'https://api.github.com/repos/mcwaage1/django/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/mcwaage1/django/events',
#   'assignees_url': 'https://api.github.com/repos/mcwaage1/django/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/mcwaage1/django/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/mcwaage1/django/tags',
#   'blobs_url': 'https://api.github.com/repos/mcwaage1/django/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/mcwaage1/django/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/mcwaage1/django/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/mcwaage1/django/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/mcwaage1/django/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/mcwaage1/django/languages',
#   'stargazers_url': 'https://api.github.com/repos/mcwaage1/django/stargazers',
#   'contributors_url': 'https://api.github.com/repos/mcwaage1/django/contributors',
#   'subscribers_url': 'https://api.github.com/repos/mcwaage1/django/subscribers',
#   'subscription_url': 'https://api.github.com/repos/mcwaage1/django/subscription',
#   'commits_url': 'https://api.github.com/repos/mcwaage1/django/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/mcwaage1/django/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/mcwaage1/django/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/mcwaage1/django/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/mcwaage1/django/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/mcwaage1/django/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/mcwaage1/django/merges',
#   'archive_url': 'https://api.github.com/repos/mcwaage1/django/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/mcwaage1/django/downloads',
#   'issues_url': 'https://api.github.com/repos/mcwaage1/django/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/mcwaage1/django/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/mcwaage1/django/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/mcwaage1/django/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/mcwaage1/django/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/mcwaage1/django/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/mcwaage1/django/deployments',
#   'created_at': '2020-10-23T04:43:18Z',
#   'updated_at': '2020-10-26T10:11:01Z',
#   'pushed_at': '2020-10-26T10:10:59Z',
#   'git_url': 'git://github.com/mcwaage1/django.git',
#   'ssh_url': 'git@github.com:mcwaage1/django.git',
#   'clone_url': 'https://github.com/mcwaage1/django.git',
#   'svn_url': 'https://github.com/mcwaage1/django',
#   'homepage': None,
#   'size': 13850,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 212783577,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMTI3ODM1Nzc=',
#   'name': 'google-homepage',
#   'full_name': 'mcwaage1/google-homepage',
#   'private': False,
#   'owner': {'login': 'mcwaage1',
#    'id': 49893491,
#    'node_id': 'MDQ6VXNlcjQ5ODkzNDkx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49893491?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mcwaage1',
#    'html_url': 'https://github.com/mcwaage1',
#    'followers_url': 'https://api.github.com/users/mcwaage1/followers',
#    'following_url': 'https://api.github.com/users/mcwaage1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mcwaage1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mcwaage1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mcwaage1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mcwaage1/orgs',
#    'repos_url': 'https://api.github.com/users/mcwaage1/repos',
#    'events_url': 'https://api.github.com/users/mcwaage1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mcwaage1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/mcwaage1/google-homepage',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/mcwaage1/google-homepage',
#   'forks_url': 'https://api.github.com/repos/mcwaage1/google-homepage/forks',
#   'keys_url': 'https://api.github.com/repos/mcwaage1/google-homepage/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/mcwaage1/google-homepage/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/mcwaage1/google-homepage/teams',
#   'hooks_url': 'https://api.github.com/repos/mcwaage1/google-homepage/hooks',
#   'issue_events_url': 'https://api.github.com/repos/mcwaage1/google-homepage/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/mcwaage1/google-homepage/events',
#   'assignees_url': 'https://api.github.com/repos/mcwaage1/google-homepage/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/mcwaage1/google-homepage/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/mcwaage1/google-homepage/tags',
#   'blobs_url': 'https://api.github.com/repos/mcwaage1/google-homepage/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/mcwaage1/google-homepage/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/mcwaage1/google-homepage/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/mcwaage1/google-homepage/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/mcwaage1/google-homepage/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/mcwaage1/google-homepage/languages',
#   'stargazers_url': 'https://api.github.com/repos/mcwaage1/google-homepage/stargazers',
#   'contributors_url': 'https://api.github.com/repos/mcwaage1/google-homepage/contributors',
#   'subscribers_url': 'https://api.github.com/repos/mcwaage1/google-homepage/subscribers',
#   'subscription_url': 'https://api.github.com/repos/mcwaage1/google-homepage/subscription',
#   'commits_url': 'https://api.github.com/repos/mcwaage1/google-homepage/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/mcwaage1/google-homepage/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/mcwaage1/google-homepage/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/mcwaage1/google-homepage/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/mcwaage1/google-homepage/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/mcwaage1/google-homepage/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/mcwaage1/google-homepage/merges',
#   'archive_url': 'https://api.github.com/repos/mcwaage1/google-homepage/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/mcwaage1/google-homepage/downloads',
#   'issues_url': 'https://api.github.com/repos/mcwaage1/google-homepage/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/mcwaage1/google-homepage/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/mcwaage1/google-homepage/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/mcwaage1/google-homepage/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/mcwaage1/google-homepage/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/mcwaage1/google-homepage/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/mcwaage1/google-homepage/deployments',
#   'created_at': '2019-10-04T09:51:04Z',
#   'updated_at': '2019-10-09T07:28:33Z',
#   'pushed_at': '2019-10-09T07:28:32Z',
#   'git_url': 'git://github.com/mcwaage1/google-homepage.git',
#   'ssh_url': 'git@github.com:mcwaage1/google-homepage.git',
#   'clone_url': 'https://github.com/mcwaage1/google-homepage.git',
#   'svn_url': 'https://github.com/mcwaage1/google-homepage',
#   'homepage': None,
#   'size': 5,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'HTML',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 300817278,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMDA4MTcyNzg=',
#   'name': 'my-first-blog',
#   'full_name': 'mcwaage1/my-first-blog',
#   'private': False,
#   'owner': {'login': 'mcwaage1',
#    'id': 49893491,
#    'node_id': 'MDQ6VXNlcjQ5ODkzNDkx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49893491?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mcwaage1',
#    'html_url': 'https://github.com/mcwaage1',
#    'followers_url': 'https://api.github.com/users/mcwaage1/followers',
#    'following_url': 'https://api.github.com/users/mcwaage1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mcwaage1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mcwaage1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mcwaage1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mcwaage1/orgs',
#    'repos_url': 'https://api.github.com/users/mcwaage1/repos',
#    'events_url': 'https://api.github.com/users/mcwaage1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mcwaage1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/mcwaage1/my-first-blog',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/mcwaage1/my-first-blog',
#   'forks_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/forks',
#   'keys_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/teams',
#   'hooks_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/hooks',
#   'issue_events_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/events',
#   'assignees_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/tags',
#   'blobs_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/languages',
#   'stargazers_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/stargazers',
#   'contributors_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/contributors',
#   'subscribers_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/subscribers',
#   'subscription_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/subscription',
#   'commits_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/merges',
#   'archive_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/downloads',
#   'issues_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/mcwaage1/my-first-blog/deployments',
#   'created_at': '2020-10-03T06:58:41Z',
#   'updated_at': '2020-10-06T08:44:20Z',
#   'pushed_at': '2020-10-06T08:44:18Z',
#   'git_url': 'git://github.com/mcwaage1/my-first-blog.git',
#   'ssh_url': 'git@github.com:mcwaage1/my-first-blog.git',
#   'clone_url': 'https://github.com/mcwaage1/my-first-blog.git',
#   'svn_url': 'https://github.com/mcwaage1/my-first-blog',
#   'homepage': None,
#   'size': 10,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 266698673,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNjY2OTg2NzM=',
#   'name': 'python',
#   'full_name': 'mcwaage1/python',
#   'private': False,
#   'owner': {'login': 'mcwaage1',
#    'id': 49893491,
#    'node_id': 'MDQ6VXNlcjQ5ODkzNDkx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49893491?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mcwaage1',
#    'html_url': 'https://github.com/mcwaage1',
#    'followers_url': 'https://api.github.com/users/mcwaage1/followers',
#    'following_url': 'https://api.github.com/users/mcwaage1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mcwaage1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mcwaage1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mcwaage1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mcwaage1/orgs',
#    'repos_url': 'https://api.github.com/users/mcwaage1/repos',
#    'events_url': 'https://api.github.com/users/mcwaage1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mcwaage1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/mcwaage1/python',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/mcwaage1/python',
#   'forks_url': 'https://api.github.com/repos/mcwaage1/python/forks',
#   'keys_url': 'https://api.github.com/repos/mcwaage1/python/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/mcwaage1/python/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/mcwaage1/python/teams',
#   'hooks_url': 'https://api.github.com/repos/mcwaage1/python/hooks',
#   'issue_events_url': 'https://api.github.com/repos/mcwaage1/python/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/mcwaage1/python/events',
#   'assignees_url': 'https://api.github.com/repos/mcwaage1/python/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/mcwaage1/python/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/mcwaage1/python/tags',
#   'blobs_url': 'https://api.github.com/repos/mcwaage1/python/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/mcwaage1/python/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/mcwaage1/python/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/mcwaage1/python/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/mcwaage1/python/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/mcwaage1/python/languages',
#   'stargazers_url': 'https://api.github.com/repos/mcwaage1/python/stargazers',
#   'contributors_url': 'https://api.github.com/repos/mcwaage1/python/contributors',
#   'subscribers_url': 'https://api.github.com/repos/mcwaage1/python/subscribers',
#   'subscription_url': 'https://api.github.com/repos/mcwaage1/python/subscription',
#   'commits_url': 'https://api.github.com/repos/mcwaage1/python/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/mcwaage1/python/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/mcwaage1/python/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/mcwaage1/python/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/mcwaage1/python/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/mcwaage1/python/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/mcwaage1/python/merges',
#   'archive_url': 'https://api.github.com/repos/mcwaage1/python/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/mcwaage1/python/downloads',
#   'issues_url': 'https://api.github.com/repos/mcwaage1/python/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/mcwaage1/python/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/mcwaage1/python/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/mcwaage1/python/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/mcwaage1/python/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/mcwaage1/python/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/mcwaage1/python/deployments',
#   'created_at': '2020-05-25T06:14:17Z',
#   'updated_at': '2020-12-31T10:25:51Z',
#   'pushed_at': '2020-12-31T10:25:48Z',
#   'git_url': 'git://github.com/mcwaage1/python.git',
#   'ssh_url': 'git@github.com:mcwaage1/python.git',
#   'clone_url': 'https://github.com/mcwaage1/python.git',
#   'svn_url': 'https://github.com/mcwaage1/python',
#   'homepage': None,
#   'size': 954,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 307337982,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMDczMzc5ODI=',
#   'name': 'qs',
#   'full_name': 'mcwaage1/qs',
#   'private': False,
#   'owner': {'login': 'mcwaage1',
#    'id': 49893491,
#    'node_id': 'MDQ6VXNlcjQ5ODkzNDkx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49893491?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mcwaage1',
#    'html_url': 'https://github.com/mcwaage1',
#    'followers_url': 'https://api.github.com/users/mcwaage1/followers',
#    'following_url': 'https://api.github.com/users/mcwaage1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mcwaage1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mcwaage1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mcwaage1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mcwaage1/orgs',
#    'repos_url': 'https://api.github.com/users/mcwaage1/repos',
#    'events_url': 'https://api.github.com/users/mcwaage1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mcwaage1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/mcwaage1/qs',
#   'description': 'Quantified Self',
#   'fork': False,
#   'url': 'https://api.github.com/repos/mcwaage1/qs',
#   'forks_url': 'https://api.github.com/repos/mcwaage1/qs/forks',
#   'keys_url': 'https://api.github.com/repos/mcwaage1/qs/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/mcwaage1/qs/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/mcwaage1/qs/teams',
#   'hooks_url': 'https://api.github.com/repos/mcwaage1/qs/hooks',
#   'issue_events_url': 'https://api.github.com/repos/mcwaage1/qs/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/mcwaage1/qs/events',
#   'assignees_url': 'https://api.github.com/repos/mcwaage1/qs/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/mcwaage1/qs/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/mcwaage1/qs/tags',
#   'blobs_url': 'https://api.github.com/repos/mcwaage1/qs/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/mcwaage1/qs/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/mcwaage1/qs/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/mcwaage1/qs/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/mcwaage1/qs/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/mcwaage1/qs/languages',
#   'stargazers_url': 'https://api.github.com/repos/mcwaage1/qs/stargazers',
#   'contributors_url': 'https://api.github.com/repos/mcwaage1/qs/contributors',
#   'subscribers_url': 'https://api.github.com/repos/mcwaage1/qs/subscribers',
#   'subscription_url': 'https://api.github.com/repos/mcwaage1/qs/subscription',
#   'commits_url': 'https://api.github.com/repos/mcwaage1/qs/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/mcwaage1/qs/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/mcwaage1/qs/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/mcwaage1/qs/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/mcwaage1/qs/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/mcwaage1/qs/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/mcwaage1/qs/merges',
#   'archive_url': 'https://api.github.com/repos/mcwaage1/qs/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/mcwaage1/qs/downloads',
#   'issues_url': 'https://api.github.com/repos/mcwaage1/qs/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/mcwaage1/qs/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/mcwaage1/qs/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/mcwaage1/qs/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/mcwaage1/qs/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/mcwaage1/qs/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/mcwaage1/qs/deployments',
#   'created_at': '2020-10-26T10:36:54Z',
#   'updated_at': '2021-01-30T11:14:29Z',
#   'pushed_at': '2021-01-30T11:14:27Z',
#   'git_url': 'git://github.com/mcwaage1/qs.git',
#   'ssh_url': 'git@github.com:mcwaage1/qs.git',
#   'clone_url': 'https://github.com/mcwaage1/qs.git',
#   'svn_url': 'https://github.com/mcwaage1/qs',
#   'homepage': None,
#   'size': 6118,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 215381721,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMTUzODE3MjE=',
#   'name': 'tributepage',
#   'full_name': 'mcwaage1/tributepage',
#   'private': False,
#   'owner': {'login': 'mcwaage1',
#    'id': 49893491,
#    'node_id': 'MDQ6VXNlcjQ5ODkzNDkx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49893491?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mcwaage1',
#    'html_url': 'https://github.com/mcwaage1',
#    'followers_url': 'https://api.github.com/users/mcwaage1/followers',
#    'following_url': 'https://api.github.com/users/mcwaage1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mcwaage1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mcwaage1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mcwaage1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mcwaage1/orgs',
#    'repos_url': 'https://api.github.com/users/mcwaage1/repos',
#    'events_url': 'https://api.github.com/users/mcwaage1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mcwaage1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/mcwaage1/tributepage',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/mcwaage1/tributepage',
#   'forks_url': 'https://api.github.com/repos/mcwaage1/tributepage/forks',
#   'keys_url': 'https://api.github.com/repos/mcwaage1/tributepage/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/mcwaage1/tributepage/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/mcwaage1/tributepage/teams',
#   'hooks_url': 'https://api.github.com/repos/mcwaage1/tributepage/hooks',
#   'issue_events_url': 'https://api.github.com/repos/mcwaage1/tributepage/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/mcwaage1/tributepage/events',
#   'assignees_url': 'https://api.github.com/repos/mcwaage1/tributepage/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/mcwaage1/tributepage/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/mcwaage1/tributepage/tags',
#   'blobs_url': 'https://api.github.com/repos/mcwaage1/tributepage/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/mcwaage1/tributepage/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/mcwaage1/tributepage/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/mcwaage1/tributepage/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/mcwaage1/tributepage/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/mcwaage1/tributepage/languages',
#   'stargazers_url': 'https://api.github.com/repos/mcwaage1/tributepage/stargazers',
#   'contributors_url': 'https://api.github.com/repos/mcwaage1/tributepage/contributors',
#   'subscribers_url': 'https://api.github.com/repos/mcwaage1/tributepage/subscribers',
#   'subscription_url': 'https://api.github.com/repos/mcwaage1/tributepage/subscription',
#   'commits_url': 'https://api.github.com/repos/mcwaage1/tributepage/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/mcwaage1/tributepage/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/mcwaage1/tributepage/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/mcwaage1/tributepage/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/mcwaage1/tributepage/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/mcwaage1/tributepage/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/mcwaage1/tributepage/merges',
#   'archive_url': 'https://api.github.com/repos/mcwaage1/tributepage/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/mcwaage1/tributepage/downloads',
#   'issues_url': 'https://api.github.com/repos/mcwaage1/tributepage/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/mcwaage1/tributepage/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/mcwaage1/tributepage/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/mcwaage1/tributepage/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/mcwaage1/tributepage/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/mcwaage1/tributepage/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/mcwaage1/tributepage/deployments',
#   'created_at': '2019-10-15T19:37:11Z',
#   'updated_at': '2019-10-17T10:48:52Z',
#   'pushed_at': '2019-10-17T10:48:51Z',
#   'git_url': 'git://github.com/mcwaage1/tributepage.git',
#   'ssh_url': 'git@github.com:mcwaage1/tributepage.git',
#   'clone_url': 'https://github.com/mcwaage1/tributepage.git',
#   'svn_url': 'https://github.com/mcwaage1/tributepage',
#   'homepage': None,
#   'size': 2,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'HTML',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'}]

# %%
len(repos)
# Out:
# 7

# %%
for repo in repos:
    print(repo['name'])
# Out:
# datascience
# django
# google-homepage
# my-first-blog
# python
# qs
# tributepage

# %%
for repo in repos:
    print(f"Name: {repo['name']} \t Created at: {repo['created_at']}")
# Out:
# Name: datascience 	 Created at: 2021-01-18T09:15:14Z
# Name: django 	 Created at: 2020-10-23T04:43:18Z
# Name: google-homepage 	 Created at: 2019-10-04T09:51:04Z
# Name: my-first-blog 	 Created at: 2020-10-03T06:58:41Z
# Name: python 	 Created at: 2020-05-25T06:14:17Z
# Name: qs 	 Created at: 2020-10-26T10:36:54Z
# Name: tributepage 	 Created at: 2019-10-15T19:37:11Z

# %%
from collections import Counter
from dateutil.parser import parse

# %%
dates = [parse(repo["created_at"]) for repo in repos]
month_counts = Counter(date.month for date in dates)
weekday_counts = Counter(date.weekday() for date in dates)

# %%
dates
# Out:
# [datetime.datetime(2021, 1, 18, 9, 15, 14, tzinfo=tzutc()),
#  datetime.datetime(2020, 10, 23, 4, 43, 18, tzinfo=tzutc()),
#  datetime.datetime(2019, 10, 4, 9, 51, 4, tzinfo=tzutc()),
#  datetime.datetime(2020, 10, 3, 6, 58, 41, tzinfo=tzutc()),
#  datetime.datetime(2020, 5, 25, 6, 14, 17, tzinfo=tzutc()),
#  datetime.datetime(2020, 10, 26, 10, 36, 54, tzinfo=tzutc()),
#  datetime.datetime(2019, 10, 15, 19, 37, 11, tzinfo=tzutc())]

# %%
month_counts
# Out:
# Counter({1: 1, 10: 5, 5: 1})

# %%
weekday_counts
# Out:
# Counter({0: 3, 4: 2, 5: 1, 1: 1})

# %%
last_5_repos = sorted(repos, key=lambda r:r["pushed_at"], reverse=True)[:5]
last_5_languages = [repo["language"] for repo in last_5_repos]
last_5_languages
# Out:
# ['Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Python',
#  'Python']

# %%
# twitter API
